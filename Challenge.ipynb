# %% [markdown]
# # Alura Voz

# %% [markdown]
# ### Importando Bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Entendendo quais informações o conjunto de dados possui
# #### Analisar quais os tipos de dados
# #### Entendendo quais informações o conjunto de dados possui

# %%
dados = pd.read_json('https://raw.githubusercontent.com/sthemonica/alura-voz/main/Dados/Telco-Customer-Churn.json')
dados
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
dados.customer[0]['gender']
# Out:
# 'Female'

# %%
dados.shape
# Out:
# (7267, 6)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
dados.customer[0]
# Out:
# {'gender': 'Female',
#  'SeniorCitizen': 0,
#  'Partner': 'Yes',
#  'Dependents': 'Yes',
#  'tenure': 9}

# %%
dados.phone[0]
# Out:
# {'PhoneService': 'Yes', 'MultipleLines': 'No'}

# %%
dados.account[0]
# Out:
# {'Contract': 'One year',
#  'PaperlessBilling': 'Yes',
#  'PaymentMethod': 'Mailed check',
#  'Charges': {'Monthly': 65.6, 'Total': '593.3'}}

# %%
dados.internet[0]
# Out:
# {'InternetService': 'DSL',
#  'OnlineSecurity': 'No',
#  'OnlineBackup': 'Yes',
#  'DeviceProtection': 'No',
#  'TechSupport': 'Yes',
#  'StreamingTV': 'Yes',
#  'StreamingMovies': 'No'}

# %%
len(dados.customer)
# Out:
# 7267

# %%
dados.customer.items()

# %%
dados.customer
# Out:
# 0       {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3       {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4       {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#                               ...
# 7262    {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# Name: customer, Length: 7267, dtype: object

# %%
_, values = zip(*dados.customer.items())

# %%
type(values)
# Out:
# tuple

# %%
values[1].keys()
# Out:
# dict_keys(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure'])

# %%
len(values)
# Out:
# 7267

# %%
print(values[0]['gender'])
# Out:
# Female

# %%
dados.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
dados.customer.items()

# %%
for item in values[1].keys():
    dados[item] = pd.Series()

dados.head()
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/1616550951.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados[item] = pd.Series()
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...

# %%
for i in np.arange(len(dados)):
    #print(values[i]['gender'])
    dados['gender'][i] = values[i]['gender']
    dados['SeniorCitizen'][i] = values[i]['SeniorCitizen']
    dados['Partner'][i] = values[i]['Partner']
    dados['Dependents'][i] = values[i]['Dependents']
    dados['tenure'][i] = values[i]['tenure']

dados
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/2589484417.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['gender'][i] = values[i]['gender']
# /Users/matheuspeixoto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/2589484417.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dados.describe()
# Out:
#        SeniorCitizen       tenure
# count    7267.000000  7267.000000
# mean        0.162653    32.346498
# std         0.369074    24.571773
# min         0.000000     0.000000
# 25%         0.000000     9.000000
# 50%         0.000000    29.000000
# 75%         0.000000    55.000000
# max         1.000000    72.000000

# %%
import matplotlib
import seaborn as sns

# %%
sns.distplot(dados.tenure)
# Out:
# /Users/matheuspeixoto/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tenure', ylabel='Density'>

# %%
((dados.query("Churn == 'Yes'  and gender == 'Female' ").count())/(dados.query("Churn == 'Yes' ")).count())*100
# Out:
# customerID       50.24077
# Churn            50.24077
# customer         50.24077
# phone            50.24077
# internet         50.24077
# account          50.24077
# gender           50.24077
# SeniorCitizen    50.24077
# Partner          50.24077
# Dependents       50.24077
# tenure           50.24077
# dtype: float64

# %%
dados.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
dados.drop(columns='customer', inplace=True)
dados
# Out:
#       customerID Churn                                              phone  \
# 0     0002-ORFBO    No     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1     0003-MKNFE    No    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2     0004-TLHLJ   Yes     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3     0011-IGKFF   Yes     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4     0013-EXCHZ   Yes     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263  9992-RRAMN   Yes    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264  9992-UJOEL    No     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265  9993-LHIEB    No     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  9995-HOTOH    No  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# ...

# %%
_, values = zip(*dados.phone.items())

# %%
for item in values[1].keys():
    dados[item] = pd.Series()

dados.head()
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/1616550951.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados[item] = pd.Series()
#    customerID Churn                                            phone  \
# 0  0002-ORFBO    No   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  0003-MKNFE    No  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2  0004-TLHLJ   Yes   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3  0011-IGKFF   Yes   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4  0013-EXCHZ   Yes   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
for i in np.arange(len(dados)):
    dados['PhoneService'][i] = values[i]['PhoneService']
    dados['MultipleLines'][i] = values[i]['MultipleLines']
    

dados.head()
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/2145061886.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['PhoneService'][i] = values[i]['PhoneService']
# /Users/matheuspeixoto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/2145061886.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dados.internet[0]
# Out:
# {'InternetService': 'DSL',
#  'OnlineSecurity': 'No',
#  'OnlineBackup': 'Yes',
#  'DeviceProtection': 'No',
#  'TechSupport': 'Yes',
#  'StreamingTV': 'Yes',
#  'StreamingMovies': 'No'}

# %%
_, values = zip(*dados.internet.items())

# %%
for item in values[1].keys():
    dados[item] = pd.Series()

dados.head()
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/1616550951.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados[item] = pd.Series()
#    customerID Churn                                            phone  \
# 0  0002-ORFBO    No   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  0003-MKNFE    No  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2  0004-TLHLJ   Yes   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3  0011-IGKFF   Yes   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4  0013-EXCHZ   Yes   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
for i in np.arange(len(dados)):
    dados['InternetService'][i] = values[i]['InternetService']
    dados['OnlineSecurity'][i] = values[i]['OnlineSecurity']
    dados['OnlineBackup'][i] = values[i]['OnlineBackup']
    dados['DeviceProtection'][i] = values[i]['DeviceProtection']
    dados['TechSupport'][i] = values[i]['TechSupport']
    dados['StreamingTV'][i] = values[i]['StreamingTV']
    dados['StreamingMovies'][i] = values[i]['StreamingMovies']

dados.head()
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/3014566385.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['InternetService'][i] = values[i]['InternetService']
# /Users/matheuspeixoto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/3014566385.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dados.drop(columns=['phone', 'internet'], inplace=True)

# %%
dados
# Out:
#       customerID Churn                                            account  \
# 0     0002-ORFBO    No  {'Contract': 'One year', 'PaperlessBilling': '...
# 1     0003-MKNFE    No  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     0004-TLHLJ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     0011-IGKFF   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     0013-EXCHZ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  9992-RRAMN   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  9992-UJOEL    No  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  9993-LHIEB    No  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  9995-HOTOH    No  {'Contract': 'Two year', 'PaperlessBilling': '...
#
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# ...

# %%
dados.account[0]
# Out:
# {'Contract': 'One year',
#  'PaperlessBilling': 'Yes',
#  'PaymentMethod': 'Mailed check',
#  'Charges': {'Monthly': 65.6, 'Total': '593.3'}}

# %%
_, values = zip(*dados.account.items())

# %%
for item in values[1].keys():
    dados[item] = pd.Series()

dados.head()
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/1616550951.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados[item] = pd.Series()
#    customerID Churn                                            account  \
# 0  0002-ORFBO    No  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  0003-MKNFE    No  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  0004-TLHLJ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  0011-IGKFF   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  0013-EXCHZ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
#
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            0.0     Yes        Yes     9.0          Yes
# 1    Male            0.0      No         No     9.0          Yes
# 2    Male            0.0      No         No     4.0          Yes
# ...

# %%
for i in np.arange(len(dados)):
    dados['Contract'][i] = values[i]['Contract']
    dados['PaperlessBilling'][i] = values[i]['PaperlessBilling']
    dados['PaymentMethod'][i] = values[i]['PaymentMethod']
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/3849294520.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Contract'][i] = values[i]['Contract']
# /Users/matheuspeixoto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/3849294520.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dados.head()
# Out:
#    customerID Churn                                            account  \
# 0  0002-ORFBO    No  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  0003-MKNFE    No  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  0004-TLHLJ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  0011-IGKFF   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  0013-EXCHZ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
#
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            0.0     Yes        Yes     9.0          Yes
# 1    Male            0.0      No         No     9.0          Yes
# 2    Male            0.0      No         No     4.0          Yes
# 3    Male            1.0     Yes         No    13.0          Yes
# 4  Female            1.0     Yes         No     3.0          Yes
#
#   MultipleLines  ... OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# ...

# %%
type(values)
# Out:
# tuple

# %%
_, values = zip(*dados.account.items())

# %%
type(values[0]['Charges'])
# Out:
# dict

# %%
values[0].get('Charges')
# Out:
# {'Monthly': 65.6, 'Total': '593.3'}

# %%
valor = []
for i in np.arange(len(dados)):
    valor.append(values[i].get('Charges'))

# %%
dados.drop(columns='Charges', inplace=True)
dados.head()
# Out:
#    customerID Churn                                            account  \
# 0  0002-ORFBO    No  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  0003-MKNFE    No  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  0004-TLHLJ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  0011-IGKFF   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  0013-EXCHZ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
#
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            0.0     Yes        Yes     9.0          Yes
# 1    Male            0.0      No         No     9.0          Yes
# 2    Male            0.0      No         No     4.0          Yes
# 3    Male            1.0     Yes         No    13.0          Yes
# 4  Female            1.0     Yes         No     3.0          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# ...

# %%
dados['Monthly'] = pd.Series()
dados['Total'] = pd.Series()
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/2444133672.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['Monthly'] = pd.Series()
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/2444133672.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['Total'] = pd.Series()

# %%
dados.head()
# Out:
#    customerID Churn                                            account  \
# 0  0002-ORFBO    No  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  0003-MKNFE    No  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  0004-TLHLJ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  0011-IGKFF   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  0013-EXCHZ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
#
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            0.0     Yes        Yes     9.0          Yes
# 1    Male            0.0      No         No     9.0          Yes
# 2    Male            0.0      No         No     4.0          Yes
# 3    Male            1.0     Yes         No    13.0          Yes
# 4  Female            1.0     Yes         No     3.0          Yes
#
#   MultipleLines  ... OnlineBackup DeviceProtection TechSupport StreamingTV  \
# ...

# %%
for i in np.arange(len(dados)):
    dados['Monthly'][i] = valor[i]['Monthly']
    dados['Total'][i] = valor[i]['Total']
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/3089647195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Monthly'][i] = valor[i]['Monthly']
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/3089647195.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Total'][i] = valor[i]['Total']
# /Users/matheuspeixoto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
dados.head()
# Out:
#    customerID Churn                                            account  \
# 0  0002-ORFBO    No  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  0003-MKNFE    No  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  0004-TLHLJ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  0011-IGKFF   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  0013-EXCHZ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
#
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            0.0     Yes        Yes     9.0          Yes
# 1    Male            0.0      No         No     9.0          Yes
# 2    Male            0.0      No         No     4.0          Yes
# 3    Male            1.0     Yes         No    13.0          Yes
# 4  Female            1.0     Yes         No     3.0          Yes
#
#   MultipleLines  ... OnlineBackup DeviceProtection TechSupport StreamingTV  \
# ...

# %%
dados.drop(columns='account', inplace=True)

# %%
dados_copia = dados.copy(deep=True)

# %%
dados_copia = dados_copia.query('Total != " " ')
dados_copia.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female            0.0     Yes        Yes     9.0
# 1  0003-MKNFE    No    Male            0.0      No         No     9.0
# 2  0004-TLHLJ   Yes    Male            0.0      No         No     4.0
# 3  0011-IGKFF   Yes    Male            1.0     Yes         No    13.0
# 4  0013-EXCHZ   Yes  Female            1.0     Yes         No     3.0
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %%
dados_copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7256 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7256 non-null   object
#  1   Churn             7256 non-null   object
#  2   gender            7256 non-null   object
#  3   SeniorCitizen     7256 non-null   float64
#  4   Partner           7256 non-null   object
#  5   Dependents        7256 non-null   object
#  6   tenure            7256 non-null   float64
#  7   PhoneService      7256 non-null   object
#  8   MultipleLines     7256 non-null   object
#  9   InternetService   7256 non-null   object
#  10  OnlineSecurity    7256 non-null   object
#  11  OnlineBackup      7256 non-null   object
#  12  DeviceProtection  7256 non-null   object
#  13  TechSupport       7256 non-null   object
#  14  StreamingTV       7256 non-null   object
#  15  StreamingMovies   7256 non-null   object
# ...

# %%
dados_copia['Total'] = dados_copia['Total'].astype(float, errors = 'raise')

# %%
dados_copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7256 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7256 non-null   object
#  1   Churn             7256 non-null   object
#  2   gender            7256 non-null   object
#  3   SeniorCitizen     7256 non-null   float64
#  4   Partner           7256 non-null   object
#  5   Dependents        7256 non-null   object
#  6   tenure            7256 non-null   float64
#  7   PhoneService      7256 non-null   object
#  8   MultipleLines     7256 non-null   object
#  9   InternetService   7256 non-null   object
#  10  OnlineSecurity    7256 non-null   object
#  11  OnlineBackup      7256 non-null   object
#  12  DeviceProtection  7256 non-null   object
#  13  TechSupport       7256 non-null   object
#  14  StreamingTV       7256 non-null   object
#  15  StreamingMovies   7256 non-null   object
# ...

# %%
dados_copia.describe()
# Out:
#        SeniorCitizen       tenure      Monthly        Total
# count      7256.0000  7256.000000  7256.000000  7256.000000
# mean          0.1629    32.395535    64.755423  2280.634213
# std           0.3693    24.558067    30.125739  2268.632997
# min           0.0000     1.000000    18.250000    18.800000
# 25%           0.0000     9.000000    35.450000   400.225000
# 50%           0.0000    29.000000    70.300000  1391.000000
# 75%           0.0000    55.000000    89.900000  3785.300000
# max           1.0000    72.000000   118.750000  8684.800000

# %%
dados.Total.replace(to_replace= " ", value = dados_copia.Total.mean(), inplace= True)

# %%
dados['Total'] = dados['Total'].astype(float, errors = 'raise')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   float64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   float64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
dados.describe()
# Out:
#        SeniorCitizen       tenure      Monthly        Total
# count    7267.000000  7267.000000  7267.000000  7267.000000
# mean        0.162653    32.346498    64.720098  2280.634213
# std         0.369074    24.571773    30.129572  2266.915104
# min         0.000000     0.000000    18.250000    18.800000
# 25%         0.000000     9.000000    35.425000   401.400000
# 50%         0.000000    29.000000    70.300000  1394.550000
# 75%         0.000000    55.000000    89.875000  3778.525000
# max         1.000000    72.000000   118.750000  8684.800000

# %%
dados.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female            0.0     Yes        Yes     9.0
# 1  0003-MKNFE    No    Male            0.0      No         No     9.0
# 2  0004-TLHLJ   Yes    Male            0.0      No         No     4.0
# 3  0011-IGKFF   Yes    Male            1.0     Yes         No    13.0
# 4  0013-EXCHZ   Yes  Female            1.0     Yes         No     3.0
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %% [markdown]
# ##### Renomeando as Colunas

# %%
dados.columns = ['Usuario', 'Taxa de Evasao', 'Genero', 'Idoso', 'Parceiro', 'Dependentes', 'Tempo de Contrato (meses)', 
                    'Servico de Telefone', 'Multiplas Linhas', 'Servico de Internet', 'Seguranca Online', 'Backup Online',
                    'Protecao de Dispositivo', 'Suporte Tecnico', 'Streaming Tv', 'Streaming Filmes', 'Contrato', 'Conta Digital',
                    'Forma de Pagamento', 'Valor Mensal', 'Valor Total']

# %%
dados.head()
# Out:
#       Usuario Taxa de Evasao  Genero  Idoso Parceiro Dependentes  \
# 0  0002-ORFBO             No  Female    0.0      Yes         Yes
# 1  0003-MKNFE             No    Male    0.0       No          No
# 2  0004-TLHLJ            Yes    Male    0.0       No          No
# 3  0011-IGKFF            Yes    Male    1.0      Yes          No
# 4  0013-EXCHZ            Yes  Female    1.0      Yes          No
#
#    Tempo de Contrato (meses) Servico de Telefone Multiplas Linhas  \
# 0                        9.0                 Yes               No
# 1                        9.0                 Yes              Yes
# 2                        4.0                 Yes               No
# 3                       13.0                 Yes               No
# 4                        3.0                 Yes               No
#
#   Servico de Internet  ... Backup Online Protecao de Dispositivo  \
# 0                 DSL  ...           Yes                      No
# ...

# %% [markdown]
# ##### Traduzindo os dados

# %%
dados.replace(['No', 'Yes', 'Female', 'Male', 'Fiber optic', 'One year', 'Month-to-month', 'Two year', 'Mailed check', 'Electronic check', 
                'Credit card (automatic)', 'Bank transfer (automatic)'], ['Nao', 'Sim', 'Feminino', 'Masculino', 'Fibra Optica', 'Um ano',
                    'Mes a mes', 'Dois anos','Cheque (e-mail)', 'Cheque (eletronico)', 'Cartao de Credito', 'Transferencia Bancaria'], inplace= True)

# %%
dados
# Out:
#          Usuario Taxa de Evasao     Genero  Idoso Parceiro Dependentes  \
# 0     0002-ORFBO            Nao   Feminino    0.0      Sim         Sim
# 1     0003-MKNFE            Nao  Masculino    0.0      Nao         Nao
# 2     0004-TLHLJ            Sim  Masculino    0.0      Nao         Nao
# 3     0011-IGKFF            Sim  Masculino    1.0      Sim         Nao
# 4     0013-EXCHZ            Sim   Feminino    1.0      Sim         Nao
# ...          ...            ...        ...    ...      ...         ...
# 7262  9987-LUTYD            Nao   Feminino    0.0      Nao         Nao
# 7263  9992-RRAMN            Sim  Masculino    0.0      Sim         Nao
# 7264  9992-UJOEL            Nao  Masculino    0.0      Nao         Nao
# 7265  9993-LHIEB            Nao  Masculino    0.0      Sim         Sim
# 7266  9995-HOTOH            Nao  Masculino    0.0      Sim         Sim
#
#       Tempo de Contrato (meses) Servico de Telefone  Multiplas Linhas  \
# ...

# %%
dados['Valor Diario'] = pd.Series()
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/1305105474.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   dados['Valor Diario'] = pd.Series()

# %%
dados.head()
# Out:
#       Usuario Taxa de Evasao     Genero  Idoso Parceiro Dependentes  \
# 0  0002-ORFBO            Nao   Feminino    0.0      Sim         Sim
# 1  0003-MKNFE            Nao  Masculino    0.0      Nao         Nao
# 2  0004-TLHLJ            Sim  Masculino    0.0      Nao         Nao
# 3  0011-IGKFF            Sim  Masculino    1.0      Sim         Nao
# 4  0013-EXCHZ            Sim   Feminino    1.0      Sim         Nao
#
#    Tempo de Contrato (meses) Servico de Telefone Multiplas Linhas  \
# 0                        9.0                 Sim              Nao
# 1                        9.0                 Sim              Sim
# 2                        4.0                 Sim              Nao
# 3                       13.0                 Sim              Nao
# 4                        3.0                 Sim              Nao
#
#   Servico de Internet  ... Protecao de Dispositivo Suporte Tecnico  \
# 0                 DSL  ...                     Nao             Sim
# ...

# %%
dados.columns
# Out:
# Index(['Usuario', 'Taxa de Evasao', 'Genero', 'Idoso', 'Parceiro',
#        'Dependentes', 'Tempo de Contrato (meses)', 'Servico de Telefone',
#        'Multiplas Linhas', 'Servico de Internet', 'Seguranca Online',
#        'Backup Online', 'Protecao de Dispositivo', 'Suporte Tecnico',
#        'Streaming Tv', 'Streaming Filmes', 'Contrato', 'Conta Digital',
#        'Forma de Pagamento', 'Valor Mensal', 'Valor Total', 'Valor Diario'],
#       dtype='object')

# %%
dados = dados[['Usuario', 'Taxa de Evasao', 'Genero', 'Idoso', 'Parceiro',
       'Dependentes', 'Tempo de Contrato (meses)', 'Servico de Telefone',
       'Multiplas Linhas', 'Servico de Internet', 'Seguranca Online',
       'Backup Online', 'Protecao de Dispositivo', 'Suporte Tecnico',
       'Streaming Tv', 'Streaming Filmes', 'Contrato', 'Conta Digital',
       'Forma de Pagamento', 'Valor Diario', 'Valor Mensal', 'Valor Total']]

dados.head()
# Out:
#       Usuario Taxa de Evasao     Genero  Idoso Parceiro Dependentes  \
# 0  0002-ORFBO            Nao   Feminino    0.0      Sim         Sim
# 1  0003-MKNFE            Nao  Masculino    0.0      Nao         Nao
# 2  0004-TLHLJ            Sim  Masculino    0.0      Nao         Nao
# 3  0011-IGKFF            Sim  Masculino    1.0      Sim         Nao
# 4  0013-EXCHZ            Sim   Feminino    1.0      Sim         Nao
#
#    Tempo de Contrato (meses) Servico de Telefone Multiplas Linhas  \
# 0                        9.0                 Sim              Nao
# 1                        9.0                 Sim              Sim
# 2                        4.0                 Sim              Nao
# 3                       13.0                 Sim              Nao
# 4                        3.0                 Sim              Nao
#
#   Servico de Internet  ... Protecao de Dispositivo Suporte Tecnico  \
# 0                 DSL  ...                     Nao             Sim
# ...

# %%
for i in np.arange(len(dados)):
    dados['Valor Diario'][i] = (dados['Valor Mensal'][i]/30)

dados.round(2).head()
# Out:
# /var/folders/9r/jvn7mvdn527f71rrrfw6535r0000gn/T/ipykernel_25778/707881072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Valor Diario'][i] = (dados['Valor Mensal'][i]/30)
#       Usuario Taxa de Evasao     Genero  Idoso Parceiro Dependentes  \
# 0  0002-ORFBO            Nao   Feminino    0.0      Sim         Sim
# 1  0003-MKNFE            Nao  Masculino    0.0      Nao         Nao
# 2  0004-TLHLJ            Sim  Masculino    0.0      Nao         Nao
# 3  0011-IGKFF            Sim  Masculino    1.0      Sim         Nao
# 4  0013-EXCHZ            Sim   Feminino    1.0      Sim         Nao
#
#    Tempo de Contrato (meses) Servico de Telefone Multiplas Linhas  \
# 0                        9.0                 Sim              Nao
# ...
